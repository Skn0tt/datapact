# %%
import pandas as pd

# %%
iris_df = pd.read_csv(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
)
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import datapact

iris_dp = datapact.test(iris_df)
iris_dp.describe("Iris dataset", "some flower data")
# iris_dp.connect(
#     server="http://localhost:3000", token="a752d76c-52d4-433b-aa2e-e5e5ac888d17"
# )
iris_dp.sepal_width.describe(unit="cm")
iris_dp.sepal_width.should.be_normal()
iris_dp.sepal_width.should.be_between(0, 3)
iris_dp.sepal_width.must.be_between(0, 3)
# Out:
# Expectation(name='be_between', success=False, critical=True, message='expected values to be at most $3$, but found $4.4$', args={'minimum': 0, 'maximum': 3}, result={'minimum': 2.0, 'maximum': 4.4}, dataframeTest=<datapact.datapact.DataframeTest object at 0x1064b0d60>)
